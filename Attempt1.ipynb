# %%
import librosa
import IPython
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline

# %%
content, sr_content = librosa.load('speech_0017.wav')

# %%
sr_content
# Out:
# 22050

# %%
IPython.display.Audio("speech_0017.wav")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
content_max, content_min = max(content), min(content)
print('Амплитудный диапазон для контента:[{}...{}]'.format(content_min, content_max))
# Out:
# Амплитудный диапазон для контента:[-0.07534298300743103...0.14569108188152313]

# %%
content_new = (content-content_min)/(content_max-content_min)*(style_max-style_min)+style_min

# %%
tuned_audio = librosa.effects.pitch_shift(content, sr_content, n_steps=6,bins_per_octave=4)

# %%
librosa.output.write_wav('new.wav',tuned_audio, sr=22050, norm=True)

# %%
IPython.display.Audio("new.wav")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.subplot(211)
plt.plot(content,c='peru')
plt.grid()
plt.title('Content')
plt.show()
plt.subplot(212)
plt.plot(tuned_audio, c='magenta')
plt.grid()
plt.title('Tuned')
plt.show()
